# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
numaralar ={"Ahmet":"0524 678 13 45","Mehmet":"0526 789 01 23","Ayse":"0532 947 38 39"}

isim = input("Numarasini istediginiz isim:")

if isim in numaralar:
    print("Istediginiz numara:",numaralar[isim])
else:
    print("Listemizde bu ismin numarasi yok...")
# Out:
# Listemizde bu ismin numarasi yok...

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
bilgiSistem ={"Enes Baris":["Aksaray","19","CEO"],"Samet Karsandi":["Aksaray","19","Bilşim Sistemleri Uzmani"],"Suleyman Yolcu":["Konya","20","Yapay Zeka Mühendisi"],"Yagiz Kaan Inevi":["Aksaray","20","Mobil Uygulama Gelistirici"] }
isim1 = input("Bilgilerini ogrenmek istediginiz kisinin ismini ve soyismini giriniz:")

if isim1 in bilgiSistem:
    bilgiler = bilgiSistem[isim1]
    print("Bilgileri bulundu.")
    print("Yasi:",bilgiler[1])
    print("Memleketi:",bilgiler[0])
    print("Pozisyonu:",bilgiler[2])
else:
    print("Bilgileri bulunamadi.")
# Out:
# Bilgileri bulundu.
# Yasi: 19
# Memleketi: Aksaray
# Pozisyonu: CEO

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
studentList = {"Enes":[75,60,80],"Samet":[100,90,99],"Ozan":[60,70,80]}

student = input("Lutfen notlarini gormek istediginiz ogrencinin ismini giriniz:")

if student in studentList:
    notlar = studentList[student]
    print("1.Sinav Notu:", notlar[0],"\n2.Sinav Notu:",notlar[1],"\n3.Sinav Notu:",notlar[2])
    print("Not Ortalamasi:",(notlar[0]+notlar[1]+notlar[2]/3))
else:
    print("Yazdiginiz isim listede bulunamadi")
# Out:
# 1.Sinav Notu: 75
#  2.Sinav Notu: 60
# 3.Sinav Notu: 80
# Not Ortalamasi: 161.66666666666666

# %% [markdown]
# # Problem 4

# %%
markalar = ["Bmw", "Mercedes", "Opel", "Mazda" ]

print(len(markalar))

print("Ilk:",markalar[0],"\nSon:",markalar[3])

markalar[3] ="Toyota"

print(markalar[-2])

print(markalar[:3])

markalar.insert(2,"Renault")
markalar.insert(3,"Toyota")

markalar.append("Audi")
markalar.append("Nissan")
print(markalar)

markalar.pop()
print(markalar)


markalar.reverse()
print(markalar)

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

liste =["studentA: Yiğit Bilgi 2010, (70,60,70)",
       "studentB: Sena Turan  1999, (80,80,70)",
       "studentC: Ahmet Turan 1998, (80,70,90) "]



print(liste)



  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

names.append("Cem")


names.insert(0, 'Sena')



names.remove("Deniz")


print("Ali" in names)

names.reverse()
print(names)

names.sort()
print(names)


years.sort()
print(years)

str = "Chevrolet,Dacia"

new = str.split(",")
print(new)


years.count(1998)

years.clear()
print(years)


marka1=input("1.markayi giriniz:")
marka2=input("2.markayi giriniz:")
marka3=input("3.markayi giriniz:")

markaListe=[marka1,marka2,marka3]
print(markaListe)
# Out:
# 4
# Ilk: Bmw
# Son: Mazda
# Opel
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Mercedes', 'Renault', 'Toyota', 'Opel', 'Toyota', 'Audi', 'Nissan']
# ['Bmw', 'Mercedes', 'Renault', 'Toyota', 'Opel', 'Toyota', 'Audi']
# ['Audi', 'Toyota', 'Opel', 'Toyota', 'Renault', 'Mercedes', 'Bmw']
# ['studentA: Yiğit Bilgi 2010, (70,60,70)', 'studentB: Sena Turan  1999, (80,80,70)', 'studentC: Ahmet Turan 1998, (80,70,90) ']
# True
# ['Cem', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# ['Ali', 'Cem', 'Hakan', 'Sena', 'Yağmur']
# [1987, 1998, 1998, 2000]
# ['Chevrolet', 'Dacia']
# []
# ['audi', 'dacia', 'renault']
